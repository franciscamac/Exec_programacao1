# %% [markdown]
# <a href="https://colab.research.google.com/github/franciscamac/Exec_programacao1/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = float(input("Informe o valor de N: "))
soma = 0
subt = 0
menu = """
INFORME O VALOR DE X
[1] - adição
[2] - subtração

---> """
x = float(input(menu))
while True:
    if(n <0) and (n> 9):
      print("Error")
      break
    elif x< 1 or x > 2:
        print("Valor de X invalido")
    elif x == 1:
        for i in range(10):
          soma = i+n
          print(n,"+" , i, "=",soma)

    elif x == 2:
        for i in range(10):
          subt = i-n
          print(n,"-", i, "=", subt)
          break
print("fim")
# Out:
# Informe o valor de N: 2
#
# INFORME O VALOR DE X
# [1] - adição
# [2] - subtração
#
# ---> 1
# 2.0 + 0 = 2.0
# 2.0 + 1 = 3.0
# 2.0 + 2 = 4.0
# 2.0 + 3 = 5.0
# 2.0 + 4 = 6.0
# 2.0 + 5 = 7.0
# 2.0 + 6 = 8.0
# 2.0 + 7 = 9.0
# 2.0 + 8 = 10.0
# 2.0 + 9 = 11.0
# 2.0 + 0 = 2.0
# 2.0 + 1 = 3.0
# 2.0 + 2 = 4.0
# 2.0 + 3 = 5.0
# 2.0 + 4 = 6.0
# 2.0 + 5 = 7.0
# 2.0 + 6 = 8.0
# 2.0 + 7 = 9.0
# 2.0 + 8 = 10.0
# 2.0 + 9 = 11.0
# 2.0 + 0 = 2.0
# 2.0 + 1 = 3.0
# 2.0 + 2 = 4.0
# 2.0 + 3 = 5.0
# 2.0 + 4 = 6.0
# 2.0 + 5 = 7.0
# 2.0 + 6 = 8.0
# 2.0 + 7 = 9.0
# 2.0 + 8 = 10.0
# 2.0 + 9 = 11.0
# 2.0 + 0 = 2.0
# 2.0 + 1 = 3.0
# 2.0 + 2 = 4.0
# 2.0 + 3 = 5.0
# 2.0 + 4 = 6.0
# 2.0 + 5 = 7.0
# 2.0 + 6 = 8.0
# 2.0 + 7 = 9.0
# 2.0 + 8 = 10.0
# 2.0 + 9 = 11.0
# 2.0 + 0 = 2.0
# 2.0 + 1 = 3.0
# 2.0 + 2 = 4.0
# 2.0 + 3 = 5.0
# 2.0 + 4 = 6.0
# 2.0 + 5 = 7.0
# 2.0 + 6 = 8.0
# 2.0 + 7 = 9.0
# 2.0 + 8 = 10.0
# 2.0 + 9 = 11.0
# 2.0 + 0 = 2.0
# 2.0 + 1 = 3.0
# 2.0 + 2 = 4.0
# 2.0 + 3 = 5.0
# 2.0 + 4 = 6.0
# ...
